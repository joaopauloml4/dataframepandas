# %%
import pandas as pd
# dataframe = pd.DataFrame()
venda = {'data': ['15/02/2021', '16/02/2021'],
'valor': [500, 300],
'produto': ['feijao', 'arroz'],
'qtde': [50, 70],
}
vendas_df = pd.DataFrame(venda)
display(vendas_df)

# %%
print(vendas_df)

# %%
import pandas as pd
bitolas_df = pd.read_excel("Bitolas.xlsx")
print(bitolas_df)
display(bitolas_df.head(12))
display(bitolas_df.describe())
display(bitolas_df.loc[bitolas_df['Madeira'] != 'x', ['B (cm)','H (cm)', 'Madeira']])
# Out:
#     B (cm)  H (cm) L (cm)    Madeira
# 0        5      11     L   Perobinha
# 1        5      15      L  Perobinha
# 2        5      20      L  Perobinha
# 3        5      25      L  Perobinha
# 4        5      30      L  Perobinha
# 5        8      30      L  Perobinha
# 6        8      40      L  Perobinha
# 7        5      15      L    Roxinho
# 8        8      15      L  Perobinha
# 9        8      10      L  Perobinha
# 10       8      20      L  Perobinha
# 11       8      30      L  Perobinha
# 12       5       6      L          x
# 13       5       7      L          x
# 14       5       5      L          x
# 15       5      10      L          x
# 16       5      35      L          x
# 17      15      15      L          x
# 18      20      20      L          x
# 19       8      25      L          x
#     B (cm)  H (cm) L (cm)    Madeira
# 0        5      11     L   Perobinha
# 1        5      15      L  Perobinha
# 2        5      20      L  Perobinha
# ...

# %%
display(vedas_df.head(12))

# %%
print(vedas_df.shape)

# %%
display(vedas_df.describe())

# %%
produtos = vedas_df['Produto']
display(produtos)

# %% [markdown]
# Não é um data frame, é uma series do pandas. pd.Series

# %%
produtosvalores_df = vedas_df[['Produto', 'Valor Unitário']]
display(produtosvalores_df)

# %%
#isplay(vedas_df.loc[2])
#uma linha
#display(vedas_df.loc[1:6])
#sequencia ou unicas

# %%
display(vedas_df.loc[1:6])
